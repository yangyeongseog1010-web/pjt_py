# %% [markdown]
# ### 불(Bool, Boolean) 자료형
#
# * bool자료형이란 `참과 거짓을 나타내는 자료형`이다.
# * bool자료형은 2가지 값인 `True` or `False`값만 가질 수 있다.
# * 주의할 점은 True와 False는 파이썬의 예약어로서 첫글자는 반드시 대문자이어야 한다.

# %% [markdown]
# ### 불 자료형은 어떻게 사용할까?

# %%
a = True
b = False
# Out:
# bool

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %% [markdown]
# 불 자료형은 조건문의 반환값으로도 사용된다.

# %%
1 == 1
# Out:
# True

# %%
2 > 1
# Out:
# True

# %%
2 < 1
# Out:
# False

# %% [markdown]
# 자료형의 참과 거짓

# %%
# a = (1, 2, 3, 4)
# a = [1, 2, 3, 0]
a = [1, 2, 3, 4]
all(a)
print(all(a))
print(type(a))
for i in a:
    print(i)
# Out:
# True
# <class 'list'>
# 1
# 2
# 3
# 4

# %%
a = [1, 2, 3, 4]
while a:
    print(a.pop()) # 리스트에서 마지막 요소를 제거
    print(a)
# Out:
# 4
# [1, 2, 3]
# 3
# [1, 2]
# 2
# [1]
# 1
# []

# %%
if [1, 2, 3]:
    print("참")
else:
    print("거짓")
# Out:
# 참

# %% [markdown]
# 위에 코드를 해석하면

# %% [markdown]
# 만약 [1, 2, 3]이 참이면 "참"이라는 문자열을 출력하고, 그렇지 않으면 "거짓"이라는 문자열을 출력하라.

# %% [markdown]
# 불 연산
#
# * bool 함수를 사용하면 자료형의 참과 거짓을 정확하게 확인할 수 있다.

# %%
bool('python')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool([1, 2, 3])
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(3)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %% [markdown]
# 논리 연산자
#
# * and
# * or
# * not

# %% [markdown]
# and 연산자
# * and 연산자는 양쪽 조건이 모두 참일 때만 True를 반환한다.

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# or 연산자
# * or 연산자는 양쪽 조건 중 하나라도 참이면 True를 반환한다.

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# not 연산자
# * not 연산자는 참과 거짓을 반대로 바꾼다.

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not 1
# Out:
# False

# %%
not 0
# Out:
# True

# %% [markdown]
# 실제 활용 예제

# %%
x = 5
y = 10
x > 0 and y > 0
# Out:
# True

# %%
x > 10 or y > 5
# Out:
# True

# %%
not (x > y)
# Out:
# True
