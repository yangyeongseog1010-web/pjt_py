# %% [markdown]
# ### 파이썬 패키지 인덱스 이란?  --> 외부 라이브러리
#
# * 정의 : 파이썬 프로그래밍 언어를 위한 소프트웨어 리포지터리(저장소)입니다.
# * 역할 : 전 세계에서 올린 프로그램들을 저장/분류/다운로드/설치 등등 할수 있는 오픈소스입니다.
# * <mark>설치 : pip install 패키지명 --> 주의 필요함</mark>
#
# > https://pypi.org/

# %% [markdown]
# #### pip --> pip은 파이썬 모듈이나 패키지를 쉽게 설치할 수 있도록 도와주는 도구이다
#
# * 모듈이나 패키지를 자동으로 함께 설치
#   > 예를 들어 B 패키지를 설치하려면 A 패키지가 먼저 필요하다면, pip은 B 패키지를 설치할 때 A 패키지도 자동으로 함께 설치해 준다.
#
# * 패키지 관리 시스템(Package Installer for Python)

# %% [markdown]
# ### <mark>pip 명령으로 설치시 주의 사항</mark>
#
# * py -m pip install "SomeProject"
# > "SomeProject"의 최신 버전을 설치
#
# * py -m pip install "SomeProject==1.4"
# > 특정 버전을 설치

# %% [markdown]
# python 3.14 환경 --> 설치

# %%
pip --version # 위에서 특정 패키지를 설치 하면 --> python 3.14 환경 --> 설치
# Out:
# pip 25.1.1 from D:\LSK\pjt_py\.venv\Lib\site-packages\pip (python 3.14)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                 Version
# ----------------------- ------------
# asttokens               3.0.2
# cloudpickle             3.1.2
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.21
# executing               2.2.1
# ipykernel               7.3.0
# ipython                 9.17.1
# ipython_pygments_lexers 1.1.1
# jedi                    0.20.0
# joblib                  1.6.0
# jupyter_client          8.10.0
# jupyter_core            5.9.1
# matplotlib-inline       0.2.2
# narwhals                2.25.0
# nest-asyncio2           1.7.2
# numpy                   2.5.3
# packaging               26.3
# parso                   0.8.7
# pip                     25.1.1
# platformdirs            4.11.7
# prompt_toolkit          3.0.53
# psutil                  7.2.2
# pure_eval               0.2.3
# Pygments                2.21.0
# python-dateutil         2.9.0.post0
# pytz                    2026.3.post1
# pyzmq                   27.2.0
# ...

# %% [markdown]
# ### cmd 창 --> pip list --> 설치 갯수가 다름
#
# * cmd로 설치하는 것은 다른 환경에 설치하는 것임
# > c:\user\woori\pip install Faker
# * 경우에 따라서 프로그램의 오류 발생

# %% [markdown]
# #### <mark>인텔리제이 터미널에서 실행해여 함</mark>

# %% [markdown]
# Faker
#
# * Faker는 테스트용 가짜 데이터를 생성할 때 사용하는 라이브러리이다.

# %%
# 현재 우리 환경은 가상환경(.venv) --> python 3.14 실행 --> 생략
패키지 관리 시스템(Package Installer for Python)  # 인텔리제이 터미널에서 실행해여 함
# Out:
#   Cell In[3], line 2
#     pip install Faker
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### %pip install faker # %매직명령어로 실행 가능

# %% [markdown]
# Faker 사용해 보기
#
# ```
# [(이름1, 주소1), (이름2, 주소2), ..., (이름30, 주소30)]
# ```

# %%
from faker import Faker
fake = Faker()
fake.name()
# Out:
# 'Christopher Chase'

# %%
fake = Faker('ko-KR')
fake.name()
# Out:
# '손도현'

# %%
fake.address()
# Out:
# '경상남도 이천시 개포거리 791'

# %% [markdown]
# 이름과 주소를 쌍으로 하는 30건의 테스트 데이터는 다음과 같이 만들 수 있다.

# %%
test_data = [(fake.name(), fake.address()) for i in range(30)]
test_data
# Out:
# [('김은서', '경상남도 청주시 서원구 잠실로 524 (성현안이마을)'),
#  ('안미숙', '울산광역시 강북구 봉은사가 121'),
#  ('박경수', '충청남도 증평군 잠실로 지하730'),
#  ('이지아', '부산광역시 서대문구 도산대296거리 651'),
#  ('김성민', '경상북도 진천군 석촌호수05로 394'),
#  ('정지아', '전북특별자치도 금산군 잠실거리 401-70'),
#  ('김숙자', '서울특별시 중랑구 양재천거리 290-31 (은주이배마을)'),
#  ('홍하윤', '강원특별자치도 원주시 서초대로 105 (도현김리)'),
#  ('김경수', '인천광역시 서초구 영동대35길 702 (정자장면)'),
#  ('박서연', '경상남도 서산시 언주917가 196'),
#  ('최은주', '전라남도 양구군 논현9로 353-43'),
#  ('이정호', '부산광역시 강서구 테헤란50길 지하818'),
#  ('장선영', '서울특별시 송파구 잠실거리 958 (준혁김이면)'),
#  ('김영숙', '강원특별자치도 서산시 압구정93거리 지하45 (성훈김마을)'),
#  ('이혜진', '전라남도 용인시 처인구 테헤란가 870-60 (경수김하면)'),
#  ('최재호', '울산광역시 영등포구 봉은사가 240 (영숙박읍)'),
#  ('서정자', '충청남도 고양시 일산동구 역삼가 581-16 (서준김동)'),
#  ('민경희', '충청남도 동해시 서초대416가 717-97 (정호김김읍)'),
#  ('박우진', '경상북도 태백시 서초대445길 384-2'),
#  ('윤명숙', '강원특별자치도 안산시 오금로 157-17'),
#  ('김영진', '충청북도 수원시 팔달구 개포995길 770 (지연한동)'),
#  ('김아름', '경상남도 당진시 양재천986길 지하913 (정자전안읍)'),
#  ('김예원', '세종특별자치시 도봉구 잠실로 706-17 (미영이허동)'),
#  ('박서영', '부산광역시 영등포구 양재천길 494'),
# ...

# %% [markdown]
# Faker 활용하기
#
# ```
# 항목	설명
# fake.name()	이름
# fake.address()	주소
# fake.postcode()	우편 번호
# fake.country()	국가명
# fake.company()	회사명
# fake.job()	직업명
# fake.phone_number()	전화 번호
# fake.email()	이메일 주소
# fake.user_name()	사용자명
# fake.pyint(min_value=0, max_value=100)	0부터 100 사이의 임의의 숫자
# fake.ipv4_private()	IP 주소
# fake.text()	임의의 문장 (한글 임의의 문장은 fake.catch_phrase() 사용)
# fake.color_name()	색상명
# ```

# %% [markdown]
# sympy
#
# * sympy는 방정식 기호(symbol)를 사용하게 해 주는 외부 라이브러리이다.

# %% [markdown]
# 인텔리제이 터미널을 이용해서 설치한다
#
# ```
# (.venv) PS D:\LSK\pjt_py> pip install sympy
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 38.2 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.3.0 sympy-1.14.0
#
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ```

# %% [markdown]
# sympy 사용해 보기
#
# * 시윤이는 가진 돈의 2/5로 학용품을 샀다고 한다.
# * 학용품을 사는 데 쓴 돈이 1,760원이라면 남은 돈은 어떻게 구하면 될까?
#
# > sympy를 사용하면 방정식을 쉽게 풀 수 있다. 먼저 다음과 같이 fractions 모듈과 sympy 모듈이 필요하다.

# %%
from fractions import Fraction
import sympy

# %%
x = sympy.symbols("x")
f = sympy.Eq(x*Fraction('2/5'), 1760)
f
# Out:
# Eq(2*x/5, 1760)

# %% [markdown]
# fractions.Fraction으로 유리수 연산하기
#
# * 파이썬에서 유리수 연산을 정확하게 하려면 fractions.Fraction을 사용해야 한다.

# %%
from fractions import Fraction
a = Fraction(1, 5)
a
# Out:
# Fraction(1, 5)

# %% [markdown]
# 또는 다음과 같이 Fraction('분자 / 분모')처럼 문자열로 만들 수도 있다.

# %%
a = Fraction('1/5')
a
# Out:
# Fraction(1, 5)

# %% [markdown]
# f라는 방정식을 세웠으므로 sympy.solve(f)로 x에 해당하는 값을 구할 수 있다.

# %%
result = sympy.solve(f)
result
# Out:
# [4400]

# %%
remains = result[0] - 1760
remains
# Out:
# 2640

# %% [markdown]
# 지금까지 내용을 종합한 풀이는 다음과 같다.

# %%
# sympy_test.py
from fractions import Fraction
import sympy

# 가지고 있던 돈을 x라고 하자.
x = sympy.symbols("x")

# 가지고 있던 돈의 2/5가 1760원이므로 방정식은 x * (2/5) = 1760 이다.
f = sympy.Eq(x*Fraction('2/5'), 1760)

# 방정식을 만족하는 값(result)을 구한다.
result = sympy.solve(f)  # 결괏값은 리스트

# 남은 돈은 다음과 같이 가지고 있던 돈에서 1760원을 빼면 된다.
remains = result[0] - 1760

print(f'남은 돈은 {remains}원입니다.')
# Out:
# 남은 돈은 2640원입니다.

# %% [markdown]
# sympy 활용

# %%
import sympy
x = sympy.symbols("x")
f = sympy.Eq(x**2, 1)
print(f)
sympy.solve(f)
# Out:
# Eq(x**2, 1)
# [-1, 1]

# %% [markdown]
# 또한 다음과 같은 연립방정식의 해도 구할 수 있다.
#
# ```
# x + y = 10
# x - y = 4
# ```

# %%
import sympy
x, y = sympy.symbols('x y')
f1 = sympy.Eq(x+y, 10)
f2 = sympy.Eq(x-y, 4)
sympy.solve([f1, f2])
# Out:
# {x: 7, y: 3}

# %% [markdown]
# 미지수가 2개 이상이면 결괏값이 리스트가 아닌 딕셔너리라는 점에 주의하자.
