# %% [markdown]
# ### 예외처리(Exception)
#
# #### 1. 에러와 예외
#
# 1. 에러(Syntex Error) : 문법에러, 파이썬은 상대적으로 문법이 간단하기 때문에 구문자체 에러 즉, 문법에러의 발생비율이 적다.
# 2. 예외(Exception) : 예외는 실행중에 발생하는 에러로서 문법에러는 없으나 프로그램이 실행 중에 더 이상 진행할 수가 없는 상태를 말한다. 예외가 발생이 되면 프로그램이 바로 중단이 된다. 이런 중단이 되는 상황을 방지하기 위해 예외처리를 해야 한다.
#
# #### 2. 예외처리 방법
#
# > `try:` <br>
#     예외가 발생할 가능이 있는 실행문자.... (예를 들면 c = b / 0) <br>
# > `except Exception:` <br>
#     예외가 발생했을 경우 실행할 문자.... (print('0으로 나눌 수 없습니다.') <br>
# > `else:` <br>
#     정상적으로 처리할 경우의 실행할 문자 <br>
# > `finally:` <br>
#     한번은 반드시 실행해야 할 문자
#
# #### 3. 예외발생과 except
#
# <img src = './images/17.예외처리_exception_01.png' width="800" height="600">
#
# #### 4. 파이썬 예외 계층도
# <img src = './images/17.예외처리_exception_02.png' width="800" height="600">

# %% [markdown]
# 오류는 언제 발생하는가?
#
# * 존재하지 않는 파일을 열려고 할 때 발생하는 오류이다.
# * 0으로 다른 숫자를 나누는 경우

# %%
f = open("나없는파일", 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = open("나없는파일", 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: '나없는파일'

# %%
4 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 4 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 마지막으로 한 가지 예를 더 들어 보자. 다음 오류는 정말 자주 발생한다.

# %%
a = [1, 2, 3]
a[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = [1, 2, 3]
# ----> 2 a[3]
#
# IndexError: list index out of range

# %% [markdown]
# #### 위에 오류 내용
#
# * a[3]은 a의 네 번째 요솟값을 가리키는데,
# * a 리스트에는 값이 3개밖에 없으므로([1, 2, 3]) 값을 얻을 수 없다
# * 따라서 IndexError 오류가 발생한다.
# * 파이썬은 이런 오류가 발생하면 프로그램을 중단하고 오류 메시지를 보여 준다.

# %% [markdown]
# #### 오류 예외 처리 기법

# %% [markdown]
# try-except 문
#
# ```
# try:
#     ...
# except [발생오류 [as 오류변수]]:
#     ...
#
# ```

# %% [markdown]
# 1. try-except만 쓰는 방법
# ```
# try:
#     ...
# except:
#     ...
#
# ```

# %% [markdown]
# 2. 발생 오류만 포함한 except
# ```
# try:
#     ...
# except 발생오류:
#     ...
#
# ```

# %% [markdown]
# 3. 발생 오류와 오류 변수까지 포함한 except 문
# ```
# try:
#     ...
# except 발생오류 as 오류변수:
#     ...
#
# ```

# %%
# try_except.py
try:
    4 / 0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# 위처럼 4를 0으로 나누려고 하면
#
# * ZeroDivisionError가 발생하여 except 블록이 실행되고,
# * 오류 변수 e에 담긴 오류 메시지를 출력할 수 있다.
# * 출력되는 오류 메시지는 다음과 같다.
# ```
# division by zero
# ```

# %% [markdown]
# #### try-finally
#
# ```
# # try_finally.py
# try:
#     f = open('foo.txt', 'w')
#     # 무언가를 수행한다.
#
#     (... 생략 ...)
#
# finally:
#     f.close()  # 중간에 오류가 발생하더라도 무조건 실행된다.
#
# ```

# %% [markdown]
# finally 절이 실제로 어떻게 동작하는지 좀 더 구체적인 예를 살펴보자.

# %%
# try_finally2.py
try:
    print("나누기 전")
    4 / 0
    print("나누기 후")
except ZeroDivisionError:
    print("오류가 발생했습니다.")
finally:
    print("finally 실행!")
# Out:
# 나누기 전
# 오류가 발생했습니다.
# finally 실행!

# %% [markdown]
# 4 / 0에서 오류가 발생했지만 finally 절은 실행된 것을 확인할 수 있다.
#
# * <mark>오류가 발생하지 않더라도 finally 절은 항상 실행된다.</mark>

# %% [markdown]
# 여러 개의 오류 처리하기
#
# ```
# try:
#     ...
# except 발생오류1:
#    ...
# except 발생오류2:
#    ...
#
# ```

# %%
# many_error.py
try:
    a = [1,2]
    print(a[3])
    4/0
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
except IndexError:
    print("인덱싱 할 수 없습니다.")
# Out:
# 인덱싱 할 수 없습니다.

# %% [markdown]
# a는 2개의 요솟값을 가지고 있으므로 a[3]이 IndexError를 발생시켜 "인덱싱 할 수 없습니다."라는 문자열을 출력한다.
#
# * <mark>왜 ZeroDivisionError 오류는 발생하지 않는가?</mark>
# * 인덱싱 오류가 먼저 발생했으므로 4 / 0에 따른 ZeroDivisionError 오류는 발생하지 않는다.

# %% [markdown]
# 오류 메시지도 다음과 같이 확인할 수 있다.

# %%
try:
    a = [1,2]
    print(a[3])
    4/0
except ZeroDivisionError as e:
    print(e)
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %% [markdown]
# ZeroDivisionError와 IndexError를 함께 처리할 수도 있다.

# %%
try:
    a = [1,2]
    print(a[3])
    4/0
except (ZeroDivisionError, IndexError) as e:
    print(e)
# Out:
# list index out of range

# %% [markdown]
# #### try-else 문
#
# ```
# try:
#     ...
# except [발생오류 [as 오류변수]]:
#     ...
# else:  # 오류가 없을 경우에만 수행
#     ...
#
# ```

# %%
# try_else.py
try:
    age=int(input('나이를 입력하세요: '))
    print(age)
except:
    print('입력이 정확하지 않습니다.')
else:
    if age <= 18:
        print('미성년자는 출입금지입니다.')
    else:
        print('환영합니다.')
# Out:
# 20
# 환영합니다.

# %% [markdown]
# #### 오류 회피하기
#
# * 코드를 작성하다 보면 특정 오류가 발생해도 그냥 통과시켜야 할 때가 있다.
# * 예를 들어, 여러 파일을 처리하는 중에 일부 파일이 없더라도 프로그램을 계속 실행하고 싶을 때가 있다.

# %%
# process_scores.py
students = ["김철수", "이영희", "박민수", "최유진"]

for student in students:
    try:
        with open(f"{student}_성적.txt", 'r') as f:
            score = f.read()
            print(f"{student}의 성적: {score}")
    except FileNotFoundError:
        print(f"{student}의 성적 파일이 없습니다. 건너뜁니다.")
        continue  # 다음 학생으로 넘어감
# Out:
# 김철수의 성적 파일이 없습니다. 건너뜁니다.
# 이영희의 성적 파일이 없습니다. 건너뜁니다.
# 박민수의 성적 파일이 없습니다. 건너뜁니다.
# 최유진의 성적 파일이 없습니다. 건너뜁니다.

# %% [markdown]
# 때로는 오류를 완전히 무시하고 싶을 때도 있다.
#
# * <mark>이럴 때 pass를 사용한다.</mark>

# %%
# error_pass.py
try:
    # 설정 파일을 읽으려 시도
    with open("설정파일.txt", 'r') as f:
        config = f.read()
except FileNotFoundError:
    pass  # 설정 파일이 없어도 계속 진행

# 프로그램의 주요 기능은 계속 수행
print("프로그램이 정상적으로 실행됩니다.")
# Out:
# 프로그램이 정상적으로 실행됩니다.

# %% [markdown]
# #### 오류 일부러 발생시키기
#
# * 프로그래밍을 하다 보면 오류를 일부러 발생시켜야 할 경우도 있다.
# * <mark>파이썬은 raise 문을 사용해 오류를 강제로 발생시킬 수 있다.</mark>

# %%
# error_raise.py
class Bird:
    def fly(self):
        raise NotImplementedError

# %% [markdown]
# Bird 클래스를 상속받는 자식 클래스는 반드시 fly 함수를 구현해야 한다는 의지를 보여 준다.
#
# * 만약 자식 클래스가 fly 함수를 구현하지 않은 상태로 fly 함수를 호출한다면 어떻게 될까?
# * <mark>NotImplementedError가 발생한다.</mark>

# %%
class Eagle(Bird):
    pass

eagle = Eagle()
eagle.fly()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[14], line 5
#       1 class Eagle(Bird):
#       2     pass
#       3
#       4 eagle = Eagle()
# ----> 5 eagle.fly()
#
# Cell In[13], line 4, in Bird.fly(self)
#       3     def fly(self):
# ----> 4         raise NotImplementedError
#
# NotImplementedError:

# %% [markdown]
# NotImplementedError가 발생하지 않게 하려면
#
# * 상속받는 클래스에서 메서드를 재구현하는 것을 <mark>'메서드 오버라이딩'</mark>이라고 한다.

# %%
class Eagle(Bird):
    def fly(self):             # 메서드 오버라이딩
        print("very fast")

eagle = Eagle()
eagle.fly()
# Out:
# very fast

# %% [markdown]
# #### 예외 만들기
#
# * 프로그램을 수행하다가 특수한 경우에만 예외 처리를 하려고 종종 예외를 직접 만들어서 사용한다.
# * <mark>이번에는 직접 예외를 만들어 보자.</mark>

# %%
# error_make.py
class MyError(Exception):
    pass

# %%
def say_nick(nick):
    if nick == '바보':
        raise MyError()
    print(nick)

# %%
say_nick("천사")
say_nick("바보")
# Out:
# 천사
# ---------------------------------------------------------------------------
# MyError                                   Traceback (most recent call last)
# Cell In[18], line 2
#       1 say_nick("천사")
# ----> 2 say_nick("바보")
#
# Cell In[17], line 3, in say_nick(nick)
#       1 def say_nick(nick):
#       2     if nick == '바보':
# ----> 3         raise MyError()
#       4     print(nick)
#
# MyError:

# %% [markdown]
# 이번에는 예외 처리 기법을 사용하여 MyError 발생을 예외 처리해 보자.

# %%
try:
    say_nick("천사")
    say_nick("바보")
except MyError:
    print("허용되지 않는 별명입니다.")
# Out:
# 천사
# 허용되지 않는 별명입니다.

# %% [markdown]
# 만약 오류 메시지를 사용하고 싶다면 다음처럼 예외 처리를 하면 된다.
#
# * 오류 메시지를 출력했을 때 오류 메시지가 보이게 하려면
# * 오류 클래스에 다음과 같은 `__str__` 메서드를 구현해야 한다.
# * <mark>`__str__` 메서드</mark>
# > print(e)처럼 오류 메시지를 print 문으로 출력할 경우에 호출되는 메서드이다.

# %% [markdown]
# <mark>마크다운에서 여기서 주의사항 Python의 메서드명은 백틱(`) 으로 감싸준 것입니다</mark>

# %%
class MyError(Exception):
    def __str__(self):
        return "허용되지 않는 별명입니다."

# %%
try:
    say_nick("천사")
    say_nick("바보")
except MyError as e:
    print(e)
# Out:
# 천사
# 허용되지 않는 별명입니다.
